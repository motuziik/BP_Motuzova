# %% [markdown]
# # Eager sweep 9
#
# Súbor: 9_1_eager_sweep_9.ipynb
#
# Program: Hospodárska informatika
#
# Vypracovala:  Veronika Motúzová
#
# Bakalárska práca: Metódy hlbokého učenia pre detekciu meteorov v astronomických snímkach
#
# Vedúci bakalárskej práce: doc. Ing. Peter Butka, PhD.
#
# Konzultant: Ing. Viera Maslej Krešňáková
#
# https://wandb.ai/motuziik/model_optimization/runs/ukijl4yj

# %% [markdown]
# Import knižníc

# %%
# BLOK 1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.layers import Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D,ZeroPadding2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import array
from sklearn.metrics import confusion_matrix, classification_report
import itertools 
from sklearn import metrics
from tensorflow.keras.callbacks import ModelCheckpoint 
from sklearn.model_selection import train_test_split

# %% [markdown]
# Načítanie a rozdelenie dát

# %%
# BLOK 2
train = np.load('../../data/zaloha-sdss/oct2019/data_final_train.npz')
test = np.load('../../data/zaloha-sdss/oct2019/data_final_test.npz')
x_train = train['train_data'].reshape(train['train_data'].shape[0], 128, 128, 1)
x_test = test['test_data'].reshape(test['test_data'].shape[0], 128, 128, 1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
y_train = to_categorical(train['train_targets'], 2)
y_test = to_categorical(test['test_targets'], 2)
X = np.concatenate([x_train,x_test])
Y = np.concatenate([y_train,y_test])
x_tr, x_test, y_tr, y_test = train_test_split(X,Y,test_size=0.1)
x_train, x_val, y_train, y_val = train_test_split(x_tr, y_tr, test_size=0.1)

# %%
# BLOK 3
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (38467, 128, 128, 1)
# (4750, 128, 128, 1)
# (4275, 128, 128, 1)
# (38467, 2)
# (4750, 2)
# (4275, 2)

# %% [markdown]
# CNN

# %%
# BLOK 4
model = Sequential()

# %%
model.add(ZeroPadding2D((1,1),input_shape=(128, 128,1)))

# %%
model.add(Conv2D(64, 3, strides=1, activation='relu'))

# %%
model.add(MaxPool2D(pool_size = 3, strides = 2))

# %%
model.add(Conv2D(64, 5, strides=1, padding='same', activation='relu'))

# %%
model.add(MaxPool2D(pool_size = 3, strides = 2))

# %%
model.add(Conv2D(64, 3, strides=1, padding='same', activation='relu'))

# %%
model.add(Conv2D(64, 3, strides=1, padding='same', activation='relu'))

# %%
model.add(MaxPool2D(pool_size = 3, strides = 2))

# %%
model.add(Flatten())

# %%
model.add(Dense(96, activation='relu'))

# %%
model.add(Dropout(0.15))

# %%
model.add(Dense(96, activation='relu'))

# %%
model.add(Dropout(0.15))

# %%
model.add(Dense(2, activation='softmax'))

# %% [markdown]
# RMSprop Optimization

# %%
# BLOK 5
optim = RMSprop()

# %%
model.compile(loss='categorical_crossentropy', optimizer=optim, metrics=['accuracy'])

# %% [markdown]
# Aby sa uložil model s najlepším výsledkom:

# %%
# BLOK 6
saved_model = "9_1_eager_sweep_9.hdf5"
checkpoint = ModelCheckpoint(saved_model, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
# BLOK 7
f = model.fit(x_train, y_train, epochs=20, batch_size=128, validation_data=(x_val, y_val), callbacks=[checkpoint])
# Out:
# Epoch 1/20
#   2/301 [..............................] - ETA: 48s - loss: 0.7021 - accuracy: 0.4609WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0770s vs `on_train_batch_end` time: 0.1219s). Check your callbacks.
# 301/301 [==============================] - ETA: 0s - loss: 0.3851 - accuracy: 0.8248
# Epoch 00001: val_accuracy improved from -inf to 0.90994, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 64s 211ms/step - loss: 0.3851 - accuracy: 0.8248 - val_loss: 0.2435 - val_accuracy: 0.9099
# Epoch 2/20
# 301/301 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9278
# Epoch 00002: val_accuracy did not improve from 0.90994
# 301/301 [==============================] - 62s 206ms/step - loss: 0.2623 - accuracy: 0.9278 - val_loss: 0.2517 - val_accuracy: 0.8858
# Epoch 3/20
# 301/301 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9536
# Epoch 00003: val_accuracy improved from 0.90994 to 0.95626, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 62s 207ms/step - loss: 0.1504 - accuracy: 0.9536 - val_loss: 0.1478 - val_accuracy: 0.9563
# Epoch 4/20
# 301/301 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9641
# Epoch 00004: val_accuracy improved from 0.95626 to 0.96164, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 62s 207ms/step - loss: 0.1149 - accuracy: 0.9641 - val_loss: 0.1147 - val_accuracy: 0.9616
# Epoch 5/20
# 301/301 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9695
# Epoch 00005: val_accuracy improved from 0.96164 to 0.97170, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 62s 207ms/step - loss: 0.1008 - accuracy: 0.9695 - val_loss: 0.0921 - val_accuracy: 0.9717
# Epoch 6/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9720
# Epoch 00006: val_accuracy did not improve from 0.97170
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0927 - accuracy: 0.9720 - val_loss: 0.1305 - val_accuracy: 0.9591
# Epoch 7/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9743
# Epoch 00007: val_accuracy did not improve from 0.97170
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0850 - accuracy: 0.9743 - val_loss: 0.2359 - val_accuracy: 0.9389
# Epoch 8/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9777
# Epoch 00008: val_accuracy improved from 0.97170 to 0.97380, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 62s 207ms/step - loss: 0.0783 - accuracy: 0.9777 - val_loss: 0.0860 - val_accuracy: 0.9738
# Epoch 9/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9798
# Epoch 00009: val_accuracy improved from 0.97380 to 0.97754, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 62s 207ms/step - loss: 0.0714 - accuracy: 0.9798 - val_loss: 0.0995 - val_accuracy: 0.9775
# Epoch 10/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0680 - accuracy: 0.9805
# Epoch 00010: val_accuracy did not improve from 0.97754
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0680 - accuracy: 0.9805 - val_loss: 0.0874 - val_accuracy: 0.9743
# Epoch 11/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9821
# Epoch 00011: val_accuracy did not improve from 0.97754
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0623 - accuracy: 0.9821 - val_loss: 0.0862 - val_accuracy: 0.9775
# Epoch 12/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9834
# Epoch 00012: val_accuracy improved from 0.97754 to 0.97801, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 62s 207ms/step - loss: 0.0640 - accuracy: 0.9834 - val_loss: 0.0823 - val_accuracy: 0.9780
# Epoch 13/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9831
# Epoch 00013: val_accuracy did not improve from 0.97801
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0639 - accuracy: 0.9831 - val_loss: 0.0814 - val_accuracy: 0.9778
# Epoch 14/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9840
# Epoch 00014: val_accuracy did not improve from 0.97801
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0569 - accuracy: 0.9840 - val_loss: 0.0916 - val_accuracy: 0.9747
# Epoch 15/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9844
# Epoch 00015: val_accuracy did not improve from 0.97801
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0554 - accuracy: 0.9844 - val_loss: 0.0890 - val_accuracy: 0.9750
# Epoch 16/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9841
# Epoch 00016: val_accuracy improved from 0.97801 to 0.98105, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 62s 207ms/step - loss: 0.0657 - accuracy: 0.9841 - val_loss: 0.0730 - val_accuracy: 0.9811
# Epoch 17/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9852
# Epoch 00017: val_accuracy did not improve from 0.98105
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0517 - accuracy: 0.9852 - val_loss: 0.0984 - val_accuracy: 0.9778
# Epoch 18/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9869
# Epoch 00018: val_accuracy did not improve from 0.98105
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0466 - accuracy: 0.9869 - val_loss: 0.0904 - val_accuracy: 0.9789
# Epoch 19/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9875
# Epoch 00019: val_accuracy improved from 0.98105 to 0.98339, saving model to 9_1_eager_sweep_9.hdf5
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0458 - accuracy: 0.9875 - val_loss: 0.0695 - val_accuracy: 0.9834
# Epoch 20/20
# 301/301 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9873
# Epoch 00020: val_accuracy did not improve from 0.98339
# 301/301 [==============================] - 62s 206ms/step - loss: 0.0482 - accuracy: 0.9873 - val_loss: 0.0932 - val_accuracy: 0.9778

# %% [markdown]
# Načítanie modelu

# %%
# BLOK 8
print("Loading model....")
model = load_model('9_1_eager_sweep_9.hdf5')
# Out:
# Loading model....

# %% [markdown]
# Vyhodnotenie test loss a accuracy

# %%
#na trénovacej množine 
score = model.evaluate(x_train, y_train, verbose=0) 
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.022698169574141502
# Test accuracy: 0.9933449625968933

# %%
# BLOK 9
#na testovacej množine
score1 = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score1[0])
print('Test accuracy:', score1[1])
# Out:
# Test loss: 0.12919846177101135
# Test accuracy: 0.9831578731536865

# %% [markdown]
# Predikcia

# %%
# BLOK 10
y_pred = model.predict(x_test)
prediction_int = np.zeros_like(y_pred)
prediction_int[y_pred > 0.5] = 1

# %% [markdown]
# Confusion Matrix

# %%
matrix = metrics.confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))

# %%
# TN / FN
# FP / TP
print(matrix)
# Out:
# [[2362   22]
#  [  58 2308]]

# %%
print(classification_report(y_test, prediction_int))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2384
#            1       0.99      0.98      0.98      2366
#
#    micro avg       0.98      0.98      0.98      4750
#    macro avg       0.98      0.98      0.98      4750
# weighted avg       0.98      0.98      0.98      4750
#  samples avg       0.98      0.98      0.98      4750

# %%
# BLOK 11
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_1 (ZeroPaddin (None, 130, 130, 1)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 64)      640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 63, 63, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 63, 63, 64)        102464
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 31, 31, 64)        36928
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 31, 31, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 14400)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 96)                1382496
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 96)                9312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 194
# =================================================================
# Total params: 1,568,962
# Trainable params: 1,568,962
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Graf modelu

# %%
# BLOK 12
tf.keras.utils.plot_model(model, "9_1_eager_sweep_9.png")

# %%
tf.keras.utils.plot_model(model, to_file='9_1_eager_sweep_9_shapes.png', show_shapes=True)

# %%
conda install -c anaconda graphviz
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.0
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     atk-1.0-2.36.0             |       h3371d22_4         560 KB  conda-forge
#     ca-certificates-2020.10.14 |                0         128 KB  anaconda
#     cairo-1.16.0               |    h6cf1ce9_1008         1.5 MB  conda-forge
#     certifi-2020.6.20          |           py38_0         160 KB  anaconda
#     cffi-1.14.3                |   py38he30daa8_0         226 KB  anaconda
#     expat-2.3.0                |       h9c3ff4c_0         168 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       h6964260_0         386 KB  anaconda
#     font-ttf-inconsolata-2.001 |       hcb22688_0          95 KB  anaconda
#     font-ttf-source-code-pro-2.030|       h7457263_0         922 KB  anaconda
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.8 MB  anaconda
#     fontconfig-2.13.1          |    hba837de_1005         357 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fribidi-1.0.10             |       h7b6447c_0         115 KB  anaconda
#     gdk-pixbuf-2.42.6          |       h04a7f16_0         609 KB  conda-forge
#     gettext-0.19.8.1           |       h9b4dc7a_1         3.7 MB  anaconda
#     graphite2-1.3.14           |       h23475e2_0         102 KB  anaconda
#     graphviz-2.47.1            |       h85b4f2f_1         4.1 MB  conda-forge
#     gtk2-2.24.33               |       h539f30e_1         7.3 MB  conda-forge
#     gts-0.7.6                  |       h64030ff_2         411 KB  conda-forge
#     harfbuzz-2.8.1             |       h83ec7ef_0         1.9 MB  conda-forge
#     libffi-3.3                 |       he6710b0_2          54 KB  anaconda
#     libgd-2.3.2                |       h78a0170_0         299 KB  conda-forge
#     libglib-2.68.2             |       h3e27bee_0         3.1 MB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     librsvg-2.50.5             |       hc3c00ef_0        17.0 MB  conda-forge
#     libtiff-4.2.0              |       hdc55705_0         633 KB  conda-forge
#     libtool-2.4.6              |    h7b6447c_1005         503 KB  anaconda
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libwebp-1.2.0              |       h3452ae3_0          85 KB  conda-forge
#     libwebp-base-1.2.0         |       h7f98852_2         815 KB  conda-forge
#     libxcb-1.14                |       h7b6447c_0         610 KB  anaconda
#     libxml2-2.9.11             |       h72842e0_0         775 KB  conda-forge
#     openssl-1.1.1h             |       h7b6447c_0         3.8 MB  anaconda
#     pango-1.48.4               |       hb8ff022_1         392 KB  conda-forge
#     pcre-8.44                  |       he6710b0_0         269 KB  anaconda
#     pixman-0.40.0              |       h7b6447c_0         628 KB  anaconda
#     python-3.8.5               |       h7579374_1        57.4 MB  anaconda
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.0.10         |       h7f98852_0          58 KB  conda-forge
#     xorg-libsm-1.2.3           |    hd9c2040_1000          26 KB  conda-forge
#     xorg-libx11-1.7.0          |       h7f98852_0         923 KB  conda-forge
#     xorg-libxext-1.3.4         |       h7f98852_1          54 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h7f98852_1003          32 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h7f98852_1002          28 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       113.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.36.0-h3371d22_4
#   cairo              conda-forge/linux-64::cairo-1.16.0-h6cf1ce9_1008
#   expat              conda-forge/linux-64::expat-2.3.0-h9c3ff4c_0
#   font-ttf-dejavu-s~ anaconda/noarch::font-ttf-dejavu-sans-mono-2.37-h6964260_0
#   font-ttf-inconsol~ anaconda/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ anaconda/noarch::font-ttf-source-code-pro-2.030-h7457263_0
#   font-ttf-ubuntu    anaconda/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-hba837de_1005
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fribidi            anaconda/linux-64::fribidi-1.0.10-h7b6447c_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.6-h04a7f16_0
#   gettext            anaconda/linux-64::gettext-0.19.8.1-h9b4dc7a_1
#   graphite2          anaconda/linux-64::graphite2-1.3.14-h23475e2_0
#   graphviz           conda-forge/linux-64::graphviz-2.47.1-h85b4f2f_1
#   gtk2               conda-forge/linux-64::gtk2-2.24.33-h539f30e_1
#   gts                conda-forge/linux-64::gts-0.7.6-h64030ff_2
#   harfbuzz           conda-forge/linux-64::harfbuzz-2.8.1-h83ec7ef_0
#   libgd              conda-forge/linux-64::libgd-2.3.2-h78a0170_0
#   libglib            conda-forge/linux-64::libglib-2.68.2-h3e27bee_0
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   librsvg            conda-forge/linux-64::librsvg-2.50.5-hc3c00ef_0
#   libtool            anaconda/linux-64::libtool-2.4.6-h7b6447c_1005
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libwebp            conda-forge/linux-64::libwebp-1.2.0-h3452ae3_0
#   libxcb             anaconda/linux-64::libxcb-1.14-h7b6447c_0
#   libxml2            conda-forge/linux-64::libxml2-2.9.11-h72842e0_0
#   pango              conda-forge/linux-64::pango-1.48.4-hb8ff022_1
#   pcre               anaconda/linux-64::pcre-8.44-he6710b0_0
#   pixman             anaconda/linux-64::pixman-0.40.0-h7b6447c_0
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.0-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#
# The following packages will be UPDATED:
#
#   libffi             conda-forge::libffi-3.2.1-he1b5a44_10~ --> anaconda::libffi-3.3-he6710b0_2
#   libtiff                                  4.1.0-h4f3a223_6 --> 4.2.0-hdc55705_0
#   libwebp-base                             1.1.0-h36c2ea0_3 --> 1.2.0-h7f98852_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.12.~ --> anaconda::ca-certificates-2020.10.14-0
#   certifi            conda-forge::certifi-2020.12.5-py38h5~ --> anaconda::certifi-2020.6.20-py38_0
#   cffi               conda-forge::cffi-1.14.4-py38ha312104~ --> anaconda::cffi-1.14.3-py38he30daa8_0
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> anaconda::openssl-1.1.1h-h7b6447c_0
#   python             conda-forge::python-3.8.6-h852b56e_0_~ --> anaconda::python-3.8.5-h7579374_1
#
#
#
# Downloading and Extracting Packages
# xorg-libsm-1.2.3     | 26 KB     | ##################################### | 100%
# xorg-libxrender-0.9. | 32 KB     | ##################################### | 100%
# font-ttf-source-code | 922 KB    | ##################################### | 100%
# gettext-0.19.8.1     | 3.7 MB    | ##################################### | 100%
# libxcb-1.14          | 610 KB    | ##################################### | 100%
# atk-1.0-2.36.0       | 560 KB    | ##################################### | 100%
# pcre-8.44            | 269 KB    | ##################################### | 100%
# libwebp-1.2.0        | 85 KB     | ##################################### | 100%
# fonts-conda-ecosyste | 4 KB      | ##################################### | 100%
# libuuid-2.32.1       | 28 KB     | ##################################### | 100%
# gts-0.7.6            | 411 KB    | ##################################### | 100%
# xorg-xextproto-7.3.0 | 28 KB     | ##################################### | 100%
# libgd-2.3.2          | 299 KB    | ##################################### | 100%
# fribidi-1.0.10       | 115 KB    | ##################################### | 100%
# pango-1.48.4         | 392 KB    | ##################################### | 100%
# gtk2-2.24.33         | 7.3 MB    | ##################################### | 100%
# xorg-libice-1.0.10   | 58 KB     | ##################################### | 100%
# fonts-conda-forge-1  | 4 KB      | ##################################### | 100%
# libiconv-1.16        | 1.4 MB    | ##################################### | 100%
# libglib-2.68.2       | 3.1 MB    | ##################################### | 100%
# font-ttf-dejavu-sans | 386 KB    | ##################################### | 100%
# xorg-kbproto-1.0.7   | 27 KB     | ##################################### | 100%
# ca-certificates-2020 | 128 KB    | ##################################### | 100%
# xorg-renderproto-0.1 | 9 KB      | ##################################### | 100%
# graphviz-2.47.1      | 4.1 MB    | ##################################### | 100%
# harfbuzz-2.8.1       | 1.9 MB    | ##################################### | 100%
# expat-2.3.0          | 168 KB    | ##################################### | 100%
# libwebp-base-1.2.0   | 815 KB    | ##################################### | 100%
# librsvg-2.50.5       | 17.0 MB   | ##################################### | 100%
# font-ttf-inconsolata | 95 KB     | ##################################### | 100%
# libxml2-2.9.11       | 775 KB    | ##################################### | 100%
# gdk-pixbuf-2.42.6    | 609 KB    | ##################################### | 100%
# fontconfig-2.13.1    | 357 KB    | ##################################### | 100%
# xorg-libxext-1.3.4   | 54 KB     | ##################################### | 100%
# cffi-1.14.3          | 226 KB    | ##################################### | 100%
# openssl-1.1.1h       | 3.8 MB    | ##################################### | 100%
# xorg-xproto-7.0.31   | 73 KB     | ##################################### | 100%
# certifi-2020.6.20    | 160 KB    | ##################################### | 100%
# font-ttf-ubuntu-0.83 | 1.8 MB    | ##################################### | 100%
# xorg-libx11-1.7.0    | 923 KB    | ##################################### | 100%
# pixman-0.40.0        | 628 KB    | ##################################### | 100%
# libtiff-4.2.0        | 633 KB    | ##################################### | 100%
# libtool-2.4.6        | 503 KB    | ##################################### | 100%
# graphite2-1.3.14     | 102 KB    | ##################################### | 100%
# libffi-3.3           | 54 KB     | ##################################### | 100%
# python-3.8.5         | 57.4 MB   | ##################################### | 100%
# cairo-1.16.0         | 1.5 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: -
# -
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge pydot
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.0
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - pydot
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     certifi-2020.12.5          |   py38h578d9bd_1         143 KB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     pydot-1.4.2                |   py38h578d9bd_0          42 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   pydot              conda-forge/linux-64::pydot-1.4.2-py38h578d9bd_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2020.10.14-0 --> conda-forge::ca-certificates-2020.12.5-ha878542_0
#   certifi                anaconda::certifi-2020.6.20-py38_0 --> conda-forge::certifi-2020.12.5-py38h578d9bd_1
#   openssl               anaconda::openssl-1.1.1h-h7b6447c_0 --> conda-forge::openssl-1.1.1k-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1k       | 2.1 MB    | ##################################### | 100%
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# pydot-1.4.2          | 42 KB     | ##################################### | 100%
# ca-certificates-2020 | 137 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge pydotplus
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.0
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pydotplus-2.0.2            |     pyh243d235_4          24 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          24 KB
#
# The following NEW packages will be INSTALLED:
#
#   pydotplus          conda-forge/noarch::pydotplus-2.0.2-pyh243d235_4
#
#
#
# Downloading and Extracting Packages
# pydotplus-2.0.2      | 24 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
